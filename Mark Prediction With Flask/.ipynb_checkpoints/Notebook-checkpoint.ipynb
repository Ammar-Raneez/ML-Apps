# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# c:\users\ammuuu\appdata\local\programs\python\python37\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
X_train = pd.read_csv("Linear_X_Train.csv").values
labels = pd.read_csv("Linear_Y_Train.csv").values

# %%
plt.scatter(X_train, labels)

# %%
from sklearn.linear_model import LinearRegression
# Out:
# c:\users\ammuuu\appdata\local\programs\python\python37\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
lr = LinearRegression(normalize=True)
lr.fit(X_train, labels)
# Out:
# LinearRegression(normalize=True)

# %%
lr.predict([[10]])
# Out:
# array([[809.16430683]])

# %%
X_test = pd.read_csv("Linear_X_Test.csv").values

# %%
plt.plot(lr.predict(X_test), color="orange")

# %%
plt.plot(X_train, lr.predict(X_train), color="orange")

# %%
import joblib

# %%
joblib.dump(lr, "model.pkl")
# Out:
# ['model.pkl']
